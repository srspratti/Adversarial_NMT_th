# %% [markdown]
# Translations using random seed

# %%
import pandas as pd
import json
# with open("test.fr-en", 'rb') as file:
#     str_file = file.read()
#     print(str_file)
#     json_file = json.load(str_file.decode('utf-8'))
#     print("json_file", json_file)
#     # print(pd.DataFrame(json.loads(file.read())))

# %%
import os

# %%
import requests
resp = requests.get("https://datasets-server.huggingface.co/first-rows?dataset=wmt14&config=fr-en&split=test")
json_data = resp.json()

# %%
# type(json_data)

# %%
# json_data['rows'][0]['row']['translation']['fr']

# %%
# json_data['rows'][0]
def get_json_data(json_data):    
    en =list()
    fr = list()
    for row_idx in json_data['rows']:
        en.append(row_idx['row']['translation']['en'])
        fr.append(row_idx['row']['translation']['fr'])
    
    return en, fr

# %%
en, fr = get_json_data(json_data)

# %%
# en

# %%
# fr

# %%
json_data_df = pd.DataFrame(list(zip(en,fr)), columns=['src','target'])

# %%
# json_data_df.iloc[0]

# %%
import deep_translator
from deep_translator import GoogleTranslator
translator = GoogleTranslator(source="auto", target='fr')

# %% [markdown]
# Translations on random indices of src

# %%
# json_data_df['ht_mt_target']
import numpy as np
import random
from random import sample
random.seed(12345)

# given data frame df

# create random index
rindex =  np.array(sample(range(len(json_data_df)), int((len(json_data_df)/2))))

print("rindex: ", rindex)
# get 10 random rows from df
# dfr = df.ix[rindex]
# Out:
# rindex:  [53 93  1 38 47 24 34 72 55 20 95 15 91 33 71 80 22 78 70 23 45 11 67 52
#  74 64 21 18 26  9 94 43 41  3 58 68 66 61 32 44 89 85  0 57 42 10 49 37
#  82 92]

# %%
json_data_df.head(10)
# Out:
#                                                  src  \
# 0              Spectacular Wingsuit Jump Over Bogota
# 1  Sportsman Jhonathan Florez jumped from a helic...
# 2  Wearing a wingsuit, he flew past over the famo...
# 3                           A black box in your car?
# 4  As America's road planners struggle to find th...
# 5  The devices, which track every mile a motorist...
# 6  The usually dull arena of highway planning has...
# 7  Libertarians have joined environmental groups ...
# 8                           The tea party is aghast.
# 9  The American Civil Liberties Union is deeply c...
#
#                                               target
# 0  Spectaculaire saut en "wingsuit" au-dessus de ...
# 1  Le sportif Jhonathan Florez a sauté jeudi d'un...
# 2  Equipé d'un wingsuit (une combinaison munie d'...
# 3               Une boîte noire dans votre voiture ?
# 4  Alors que les planificateurs du réseau routier...
# 5  Les appareils, qui enregistrent tous les miles...
# 6  Le secteur généralement sans intérêt de la pla...
# 7  Les libertaires ont rejoint des groupes écolog...
# 8                          Le Tea Party est atterré.
# 9  L'American Civil Liberties Union est elle auss...

# %%
def translate_with_max_length(text, max_length=50):
    # Translate the text to French
    translated_text = translator.translate(text)

    # Check if the translated text is within the desired maximum length
    if len(translated_text) <= max_length:
        return translated_text
    else:
        # Truncate the translated text to the maximum length
        return translated_text[:max_length]

# %%
# Iterate through DataFrame rows
for i, row in json_data_df.iterrows():
    if i in rindex:
        # Translate the 'src' column and limit to max_len 50
        translated_text = translate_with_max_length(row['src'], max_length=50)
        json_data_df.loc[i, 'ht_mt_target'] = translated_text
        json_data_df.loc[i, 'ht_mt_label'] = '0'
    else:
        # Use the original 'target' column
        json_data_df.loc[i, 'ht_mt_target'] = row['target']
        json_data_df.loc[i, 'ht_mt_label'] = '1'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb Cell 18 line 5
#       <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> for i, row in json_data_df.iterrows():
#       <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     if i in rindex:
#       <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>         # Translate the 'src' column and limit to max_len 50
# ----> <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>         translated_text = translate_with_max_length(row['src'], max_length=50)
#       <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>         json_data_df.loc[i, 'ht_mt_target'] = translated_text
#       <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         json_data_df.loc[i, 'ht_mt_label'] = '0'
#
# /u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb Cell 18 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def translate_with_max_length(text, max_length=50):
#       <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     # Translate the text to French
# ----> <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     translated_text = translator.translate(text).text
#       <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     # Check if the translated text is within the desired maximum length
#       <a href='vscode-notebook-cell://ssh-remote%2Boctal27/u/prattisr/phase-2/all_repos/Adversarial_NMT/neural-machine-translation-using-gan-master/wmt14_to_invidual_files_En_Fr.ipynb#X60sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     if len(translated_text) <= max_length:
#
# AttributeError: 'str' object has no attribute 'text'

# %%
# json_data_df.ix[rindex] 
# for row in json_data_df.ix[] 
# for row in rindex:
#     print("json_data_df[row] ", json_data_df.iloc[row])
    # if json_data_df.ix[row]
    # print("row: ", row)
    
# for row in rindex:
#     json_data_df.ix[row]
# for i, row in json_data_df.iterrows():
#     if i in rindex:
#         json_data_df.loc[i, 'ht_mt_target'] = translator.translate(json_data_df.loc[i, 'src'])
#         json_data_df.loc[i, 'ht_mt_label'] = '0'
#     else:
#         json_data_df.loc[i, 'ht_mt_target'] = json_data_df.loc[i, 'target']
#         json_data_df.loc[i, 'ht_mt_label'] = '1'

# %%
json_data_df
# Out:
#                                                   src  \
# 0               Spectacular Wingsuit Jump Over Bogota
# 1   Sportsman Jhonathan Florez jumped from a helic...
# 2   Wearing a wingsuit, he flew past over the famo...
# 3                            A black box in your car?
# 4   As America's road planners struggle to find th...
# ..                                                ...
# 95  It is therefore not surprising that he should ...
# 96  He appears in one of their adverts, broadcast ...
# 97  The Minister of Defence, Rob Nicholson, insist...
# 98  Attacked by liberals and neo-democrats in the ...
# 99  "All injured soldiers receive the appropriate ...
#
#                                                target  \
# 0   Spectaculaire saut en "wingsuit" au-dessus de ...
# 1   Le sportif Jhonathan Florez a sauté jeudi d'un...
# 2   Equipé d'un wingsuit (une combinaison munie d'...
# 3                Une boîte noire dans votre voiture ?
# 4   Alors que les planificateurs du réseau routier...
# ..                                                ...
# 95  Rien d'étonnant à ce qu'il ait donc un masque ...
# 96  Il apparaîtra dans un de leurs spots publicita...
# 97  Le ministre de la Défense, Rob Nicholson, a in...
# 98  Attaqué par les libéraux et les néo-démocrates...
# 99  Tous les soldats blessés reçoivent les soins a...
#
#                                          ht_mt_target ht_mt_label
# 0   Saut spectaculaire en Wingsuit au-dessus de Bo...           0
# 1   Le sportif Jhonathan Florez a sauté jeudi d'un...           0
# 2   Equipé d'un wingsuit (une combinaison munie d'...           1
# 3                Une boîte noire dans votre voiture ?           0
# 4   Alors que les planificateurs du réseau routier...           1
# ..                                                ...         ...
# 95  Il n'est donc pas étonnant qu'il porte un masq...           0
# 96  Il apparaîtra dans un de leurs spots publicita...           1
# 97  Le ministre de la Défense, Rob Nicholson, a in...           1
# 98  Attaqué par les libéraux et les néo-démocrates...           1
# 99  Tous les soldats blessés reçoivent les soins a...           1
#
# [100 rows x 4 columns]

# %%
idx = np.where((json_data_df['ht_mt_label']=='0'))

# %%
json_data_df.loc[idx]
# Out:
#                                                   src  \
# 0               Spectacular Wingsuit Jump Over Bogota
# 1   Sportsman Jhonathan Florez jumped from a helic...
# 3                            A black box in your car?
# 9   The American Civil Liberties Union is deeply c...
# 10  And while Congress can't agree on whether to p...
# 11  They are exploring how, over the next decade, ...
# 15  There is going to be a change in how we pay th...
# 18   Americans don't buy as much gas as they used to.
# 20  The federal tax itself, 18.4 cents per gallon,...
# 21  Politicians are loath to raise the tax even on...
# 22  "The gas tax is just not sustainable," said Le...
# 23  His state recently put tracking devices on 500...
# 24  "This works out as the most logical alternativ...
# 26  It is no surprise that the idea appeals to urb...
# 32  The movement is also bolstered by two former U...
# 33  The U.S. Senate approved a $90-million pilot p...
# 34  But the House leadership killed the proposal, ...
# 37  Those drivers will soon pay the mileage fees i...
# 38              Nevada has already completed a pilot.
# 41  And the I-95 Coalition, which includes 17 stat...
# 42                The concept is not a universal hit.
# 43  In Nevada, where about 50 volunteers' cars wer...
# 44  "Concerns about Big Brother and those sorts of...
# 45                It was not something people wanted.
# 47  There is no need to build an enormous, unwield...
# 49  If you can do that, Khan said, the public gets...
# 52  It was seeking to break into an emerging marke...
# 53  But the devices it is testing appeal to highwa...
# 55  There have been some big mistakes in some of t...
# 57  In Oregon, planners are experimenting with giv...
# 58      They can choose a device with or without GPS.
# 61  In New York City, transportation officials are...
# 64  At the Metropolitan Transportation Commission ...
# 66  "There is no need for radical surgery when all...
# 67  If we do this, hundreds of millions of drivers...
# 68       David Bowie: Four Unpublished Songs Released
# 70  Following The Next Day, released in January, h...
# 71        Four have already appeared on the Internet.
# 72  The announcement that David Bowie was releasin...
# 74  After ten years of silence (his last record, R...
# 78  He put together a real feast for his fans to m...
# 80  The Next Day Extra had a total of ten addition...
# 82  In it, he presents each of the disks plus the ...
# 85  However, Atomica is not the only track to have...
# 89  Either way, with this cheerful track, the sing...
# 91  On Born in a UFO, David Bowie once again refer...
# 92  The spellbinding guitar riffs make you want to...
# 93  In any case, Bowie enjoys playing the chameleo...
# 94  He veils and reveals at the same time, and lik...
# 95  It is therefore not surprising that he should ...
#
#                                                target  \
# 0   Spectaculaire saut en "wingsuit" au-dessus de ...
# 1   Le sportif Jhonathan Florez a sauté jeudi d'un...
# 3                Une boîte noire dans votre voiture ?
# 9   L'American Civil Liberties Union est elle auss...
# 10  Et tandis que les membres du Congrès n'arriven...
# 11  Ils cherchent comment, au cours de la prochain...
# 15  Il va y avoir du changement dans la façon dont...
# 18  Les Américains n'achètent plus autant d'essenc...
# 20  La taxe fédérale elle-même, qui est de 18,4 ce...
# 21  Les hommes politiques sont réticents à augment...
# 22  « La taxe sur l'essence n'est tout simplement ...
# 23  Son État a récemment fait installer des traceu...
# 24  « Cela s'avère être l'alternative la plus logi...
# 26  Il n'est pas surprenant que l'idée séduise les...
# 32  Le mouvement est également soutenu par deux an...
# 33  Le Sénat américain a approuvé un projet pilote...
# 34  Mais la présidence de la Chambre a tué la prop...
# 37  Ces automobilistes paieront bientôt à l'État d...
# 38    Le Nevada a déjà mené à terme un projet pilote.
# 41  Et la coalition I-95, qui comprend 17 agences ...
# 42          Le concept n'est pas un succès universel.
# 43  Dans le Nevada, où environ 50 automobilistes v...
# 44  « Les inquiétudes au sujet de Big Brother et c...
# 45   Ce n'est pas quelque chose que les gens veulent.
# 47  Il n'est pas nécessaire de construire une infr...
# 49  Si on peut faire ça, a ajouté Khan, les citoye...
# 52  Elle cherchait à percer dans le marché émergen...
# 53  Mais les appareils qu'elle teste ont plu aux p...
# 55  De grosses erreurs ont été commises dans les p...
# 57  Dans l'Oregon, les planificateurs tentent l'ex...
# 58  Ils peuvent choisir un appareil avec ou sans GPS.
# 61  Dans la ville de New York, les responsables de...
# 64  À la Metropolitan Transportation Commission de...
# 66  « Il n'est pas nécessaire de recourir à une ch...
# 67  Si on fait ça, des centaines de millions d'aut...
# 68              David Bowie: quatre inédits en écoute
# 70  À partir de The Next Day, paru en janvier, il ...
# 71               Quatre ont déjà émergé sur la Toile.
# 72  L'annonce de la parution d'un nouvel album de ...
# 74  Après dix ans de silence (le dernier disque, R...
# 78  Pour l'occasion, il a concocté un vrai festin ...
# 80  The Next Day Extra contiendra au total dix tit...
# 82  Il y introduit à la fois chacun des disques, m...
# 85  Mais Atomica n'est pas le seul titre à dévoile...
# 89  Avec ce titre enjoué, le chanteur semble en to...
# 91  Sur Born In A UFO, David Bowie fait une nouvel...
# 92  Les riffs de guitare, envoûtants, donnent envi...
# 93  Bowie s'amuse en tout cas à jouer au caméléon ...
# 94  Il dissimule et révèle à la fois, joue à adopt...
# 95  Rien d'étonnant à ce qu'il ait donc un masque ...
#
#                                          ht_mt_target ht_mt_label
# 0   Saut spectaculaire en Wingsuit au-dessus de Bo...           0
# 1   Le sportif Jhonathan Florez a sauté jeudi d'un...           0
# 3                Une boîte noire dans votre voiture ?           0
# 9   L'Union américaine des libertés civiles est ég...           0
# 10  Et même si le Congrès ne parvient pas à se met...           0
# 11  Ils étudient comment, au cours de la prochaine...           0
# 15  Il va y avoir un changement dans la façon dont...           0
# 18  Les Américains n’achètent plus autant d’essenc...           0
# 20  La taxe fédérale elle-même, 18,4 cents le gall...           0
# 21  Les politiciens sont réticents à augmenter la ...           0
# 22  "La taxe sur l'essence n'est tout simplement p...           0
# 23  Son État a récemment installé des dispositifs ...           0
# 24  "Cela s'avère être l'alternative la plus logiq...           0
# 26  Il n’est pas surprenant que l’idée séduise les...           0
# 32  Le mouvement est également soutenu par deux an...           0
# 33  Le Sénat américain a approuvé l’année dernière...           0
# 34  Mais les dirigeants de la Chambre ont rejeté l...           0
# 37  Ces conducteurs paieront bientôt à l’État les ...           0
# 38         Le Nevada a déjà réalisé un projet pilote.           0
# 41  Et la Coalition I-95, qui comprend 17 départem...           0
# 42          Le concept n’est pas un succès universel.           0
# 43  Au Nevada, où environ 50 voitures de volontair...           0
# 44  "Les inquiétudes concernant Big Brother et ce ...           0
# 45  Ce n’était pas quelque chose que les gens voul...           0
# 47  Il n'est pas nécessaire de construire une infr...           0
# 49  Si vous y parvenez, a déclaré Khan, le public ...           0
# 52  Elle cherchait à pénétrer le marché émergent d...           0
# 53  Mais les appareils testés séduisent les planif...           0
# 55  De grosses erreurs ont été commises dans certa...           0
# 57  Dans l’Oregon, les planificateurs tentent d’of...           0
# 58  Ils peuvent choisir un appareil avec ou sans GPS.           0
# 61  À New York, les responsables des transports ch...           0
# 64  À la Commission métropolitaine des transports ...           0
# 66  "Il n'est pas nécessaire de recourir à une int...           0
# 67  Si nous faisons cela, des centaines de million...           0
# 68   David Bowie : sortie de quatre chansons inédites           0
# 70  Après The Next Day, sorti en janvier, il a con...           0
# 71             Quatre sont déjà apparus sur Internet.           0
# 72  L'annonce de la sortie d'un nouvel album de Da...           0
# 74  Après dix ans de silence (son dernier disque, ...           0
# 78  Il a organisé un véritable festin pour ses fan...           0
# 80  Le Next Day Extra comptait au total dix titres...           0
# 82  Il y présente chacun des disques ainsi que les...           0
# 85  Cependant, Atomica n’est pas le seul morceau à...           0
# 89  Quoi qu'il en soit, avec ce titre enjoué, le c...           0
# 91  Sur Born in a UFO, David Bowie évoque une nouv...           0
# 92  Les riffs de guitare envoûtants donnent envie ...           0
# 93  En tout cas, Bowie s'amuse à jouer au caméléon...           0
# 94  Il voile et dévoile à la fois, et aime assumer...           0
# 95  Il n'est donc pas étonnant qu'il porte un masq...           0

# %% [markdown]
# Writing files to test_classify/...

# %%
if not os.path.exists('test_classify_data/wmt14_en_fr_test/'):
    os.makedirs('test_classify_data/wmt14_en_fr_test')
output_path = 'test_classify_data/wmt14_en_fr_test/'

# %%
with open(os.path.join(output_path, "ht_mt_target.fr"), 'w') as json_to_txt_v:
    for row in json_data_df['ht_mt_target'].values:
        json_to_txt_v.writelines(row)
        json_to_txt_v.write("\n")#.encode('utf-8')")

# %%
with open(os.path.join(output_path, "src.en"), 'w') as json_to_txt_v:
    for row in json_data_df['src'].values:
        json_to_txt_v.writelines(row)
        json_to_txt_v.write("\n")#.encode('utf-8')")

# %%
with open(os.path.join(output_path,"target.fr"), 'w') as json_to_txt_v:
    for row in json_data_df['target'].values:
        json_to_txt_v.writelines(row)
        json_to_txt_v.write("\n")#.encode('utf-8')")

# %%
with open(os.path.join(output_path,"ht_mt_label"), 'w') as json_to_txt_v:
    for row in json_data_df['ht_mt_label']:
        json_to_txt_v.write(str(row))
        json_to_txt_v.write("\n")#.encode('utf-8')")
